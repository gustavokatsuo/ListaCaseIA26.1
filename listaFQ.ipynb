# %% [markdown]
# # **Lista de Exercícios: Revisão Teórica do Módulo 01**

# %% [markdown]
# ## **Módulo 1.1: Notação de Conjuntos e Espaços de Probabilidade**

# %% [markdown]
# **Questão 1:** Na modelagem de ativos financeiros, frequentemente trabalhamos com o conceito de "Espaço de Probabilidade". Descreva os três elementos que compõem a tripla $(\Omega, \mathcal{F}, P)$ e explique, com suas palavras, por que a sigma-álgebra ($\mathcal{F}$) é necessária para garantir a consistência do modelo.
#
# **Questão 2:** Defina formalmente o que é um **Evento** dentro da teoria das probabilidades e explique a diferença entre um resultado individual do espaço amostral ($\omega \in \Omega$) e um evento ($A \in \mathcal{F}$).
#
# **Questão 3:** Considere um dado de 6 faces representando cenários de retorno de um ativo. Demonstre a aplicação da **Aditividade Contável** para calcular a probabilidade de um evento $A$ (resultado par), considerando que os resultados são mutuamente exclusivos.

# %% [markdown]
# ## **Módulo 1.2: Variáveis Aleatórias e Momentos Estatísticos**

# %% [markdown]
# **Questão 4:** Explique a diferença fundamental entre uma Variável Aleatória **Discreta** e uma **Contínua** no contexto financeiro. Forneça um exemplo de cada (ex: número de trades vs. retorno logarítmico).
#
# **Questão 5:** A Função de Distribuição Acumulada (CDF), denotada por $F_X(x) = P(X \leq x)$, é uma ferramenta poderosa. Como podemos utilizar a CDF para calcular a probabilidade de um retorno estar em um intervalo específico $[a, b]$, ou seja, $P(a < X \leq b)$?
#
# **Questão 6:** Os momentos estatísticos resumem as características de uma distribuição. Relacione cada um dos quatro primeiros momentos (Média, Variância, Assimetria e Curtose) com uma interpretação prática no gerenciamento de risco de um portfólio.
#
# **Questão 7:** O que significa dizer que uma distribuição financeira apresenta **"Caudas Pesadas" (Fat Tails)**? Qual momento estatístico é o principal indicador dessa característica e por que isso é um sinal de alerta para modelos que assumem a normalidade?

# %% [markdown]
# ## **Módulo 1.3: Processos Estocásticos e Dependência**

# %% [markdown]
# **Questão 8:** Um processo estocástico descreve a evolução da incerteza ao longo do tempo. Diferencie um processo de **Tempo Discreto** de um de **Tempo Contínuo**, citando um exemplo de série temporal financeira para cada.
#
# **Questão 9:** A independência de eventos é definida por $P(A \cap B) = P(A) \cdot P(B)$. Explique por que a independência aos pares não garante a **Independência Mútua** em uma coleção de múltiplos eventos.
#
# **Questão 10:** O Teorema de Bayes permite atualizar probabilidades com novas evidências. Identifique os componentes (Prior, Posterior, Verossimilhança e Evidência) na fórmula abaixo:
# $$P(A|B) = \frac{P(B|A) \cdot P(A)}{P(B)}$$
#
# **Questão 11:** Diferencie **Covariância** de **Correlação**. Por que a correlação é considerada uma medida padronizada e o que significa uma correlação de zero em termos de relação linear e independência?

# %% [markdown]
# ## **Módulo 1.4: Distribuições de Probabilidade em Finanças**

# %% [markdown]
# **Questão 12:** A Distribuição **Exponencial** modela tempos entre eventos. Explique a propriedade de **"Falta de Memória"** e como ela se aplica ao tempo de espera por uma nova negociação em bolsa.
#
# **Questão 13:** Cite três limitações da Distribuição **Normal (Gaussiana)** quando aplicada a retornos de ativos reais, mencionando conceitos como curtose e eventos extremos.
#
# **Questão 14:** Por que a Distribuição **Log-Normal** é frequentemente preferida para modelar o **preço** de uma ação, enquanto a Normal é usada para os **retornos logarítmicos**?
#
# **Questão 15:** Na Distribuição **t de Student**, qual é a função do parâmetro de "Graus de Liberdade" ($\nu$)? Como o comportamento dessa distribuição se altera quando $\nu$ assume valores baixos (ex: $\nu=3$) versus valores altos (ex: $\nu>30$)?

# %% [markdown]
# # **Lista de Exercícios: Revisão Teórica do Módulo 02**

# %% [markdown]
# ## **Módulo 2.1: Coleta e Preparação de Dados Financeiros**

# %% [markdown]
# **Questão 1:** No mercado financeiro, a estrutura de dados mais comum para representar a variação de preços em um intervalo de tempo é o formato **OHLC**. Descreva o que cada uma dessas quatro letras representa e explique por que o uso do **Fechamento Ajustado (Adjusted Close)** é fundamental ao realizar análises de longo prazo em ativos que pagam dividendos ou sofrem desdobramentos (splits).
#
# **Questão 2:** Ao coletar dados com a biblioteca `yfinance`, é frequente encontrar lacunas ou inconsistências. Cite duas estratégias de limpeza de dados (como o preenchimento de *NaNs*) mencionadas no material e explique por que simplesmente excluir linhas com dados faltantes (`dropna`) pode ser prejudicial para o cálculo de indicadores que dependem de janelas temporais contínuas.
#
# **Questão 3:** Defina matematicamente a diferença entre o **Retorno Simples** e o **Retorno Logarítmico**. Por que os retornos logarítmicos são amplamente preferidos em Finanças Quantitativas quando se trata de agregar (somar) retornos ao longo do tempo?

# %% [markdown]
# ## **Módulo 2.2: Indicadores de Tendência**

# %% [markdown]
# **Questão 4:** As Médias Móveis são ferramentas fundamentais para suavizar o "ruído" dos preços e identificar a direção principal do mercado. Explique a diferença de cálculo e de sensibilidade entre a **Média Móvel Simples (SMA)** e a **Média Móvel Exponencial (EMA)**. Qual delas um analista deve escolher se o objetivo for reagir o mais rápido possível a uma mudança brusca de preço recente?
#
# **Questão 5:** O **VWAP (Volume Weighted Average Price)** é frequentemente referido como o "preço justo" de uma sessão de negociação. Como a inclusão do volume no cálculo do VWAP o torna diferente de uma média móvel comum e por que grandes investidores institucionais o utilizam como referência para suas execuções?
#
# **Questão 6:** O indicador **ADX (Average Directional Index)** possui uma característica peculiar: ele não indica se a tendência é de alta ou de baixa. Explique o que o ADX efetivamente mede e como os indicadores auxiliares **+DI** e **-DI** são usados em conjunto com ele para determinar a direção do movimento.

# %% [markdown]
# ## **Módulo 2.3: Indicadores de Momentum e Volatilidade**

# %% [markdown]
# **Questão 7:** O **RSI (Índice de Força Relativa)** é um oscilador que mede a velocidade e a mudança dos movimentos de preços em uma escala de 0 a 100. Defina os níveis clássicos de "Sobrecompra" e "Sobrevenda" e descreva o que é uma **Divergência de RSI**, explicando por que ela é considerada um sinal de possível reversão de tendência.
#
# **Questão 8:** As **Bandas de Bollinger** são compostas por uma média móvel central e duas bandas laterais baseadas no desvio padrão dos preços. Explique como a distância entre as bandas se comporta em períodos de alta e baixa volatilidade e descreva o fenômeno conhecido como *"The Squeeze"* (Estreitamento).
#
# **Questão 9:** Diferente de outros indicadores, o **ATR (Average True Range)** não indica a direção do preço, mas sim a sua volatilidade em termos nominais. Como um analista quantitativo pode utilizar o valor do ATR para definir um *Stop Loss* que se ajuste automaticamente à "agitação" atual do mercado?

# %% [markdown]
# ## **Módulo 2.4: Indicadores de Volume**

# %% [markdown]
# **Questão 10:** O **OBV (On Balance Volume)** relaciona o volume financeiro às variações de preço para medir a pressão de compra e venda. Explique a regra de cálculo do OBV (em que condições o volume do dia é somado ou subtraído) e descreva o que sinaliza uma situação onde o preço de uma ação está subindo, mas o OBV está caindo ou estagnado.
#
# **Questão 11:** O **Volume Oscillator** busca identificar tendências no volume através da diferença entre duas médias móveis (uma curta e uma longa). Qual é a interpretação técnica de um Volume Oscillator subindo acima de zero durante um rompimento de resistência no preço?
#
# **Questão 12:** Retomando o conceito de **VWAP**, explique por que ele também é classificado como um indicador de volume e de que forma ele ajuda a identificar se um ativo está sendo negociado acima ou abaixo do preço médio ponderado pelo volume do dia.

# %% [markdown]
# # **Lista de Exercícios: Revisão Teórica do Módulo 03**

# %% [markdown]
# ## **Módulo 3.1: Fundamentos de Séries Temporais**

# %% [markdown]
# **Questão 1:** Uma série temporal é uma sequência de dados observados em intervalos de tempo sucessivos. Explique a diferença entre os quatro componentes clássicos de uma série temporal: **Tendência**, **Sazonalidade**, **Ciclo** e **Ruído (Erro Aleatório)**.
#
# **Questão 2:** A decomposição de uma série pode ser feita de forma **Aditiva** ou **Multiplicativa**. Em que situação prática um analista deve optar pelo modelo multiplicativo em vez do aditivo ao analisar o preço de um ativo ou o volume de vendas?
#
# **Questão 3:** O que significa o processo de **Estimação de Componentes** e qual é a utilidade de "dessazonalizar" uma série temporal antes de realizar uma projeção de preços?

# %% [markdown]
# ## **Módulo 3.2: Estacionariedade em Séries Temporais**

# %% [markdown]
# **Questão 4:** O conceito de **Estacionariedade Fraca (ou de Segunda Ordem)** é a base para a modelagem preditiva. Quais são as três condições matemáticas que uma série deve satisfazer para ser considerada fracamente estacionária?
#
# **Questão 5:** A análise visual de correlogramas é uma ferramenta diagnóstica poderosa. Explique a diferença entre a **Função de Autocorrelação (ACF)** e a **Função de Autocorrelação Parcial (PACF)**. O que um decaimento muito lento na ACF costuma indicar sobre a estacionariedade da série?
#
# **Questão 6:** Para confirmar a estacionariedade de forma rigorosa, utilizamos testes de hipótese. Diferencie o **Teste Dickey-Fuller Aumentado (ADF)** do **Teste KPSS**. Qual é a hipótese nula ($H_0$) de cada um e o que significa quando eles apresentam resultados conflitantes?
#
# **Questão 7:** Se uma série financeira (como o preço de uma ação) não é estacionária, qual é o procedimento padrão de transformação (geralmente denotado pelo parâmetro $d$ no modelo ARIMA) para tentar torná-la estacionária?

# %% [markdown]
# ## **Módulo 3.3: Modelos ARIMA e GARCH**

# %% [markdown]
# **Questão 8:** Os modelos **ARIMA(p, d, q)** são compostos por três partes fundamentais. Explique o que representam os parâmetros **p** (Auto-regressivo), **d** (Integração) e **q** (Média Móvel) e como a identificação desses termos ajuda a modelar a memória de uma série temporal.
#
# **Questão 9:** Diferencie um processo **AR(1)** de um processo **MA(1)**. Como o comportamento da Função de Autocorrelação (ACF) e da Função de Autocorrelação Parcial (PACF) nos ajuda a decidir qual desses dois modelos é mais adequado para os dados?
#
# **Questão 10:** O que é a **Heterocedasticidade Condicional** e por que ela invalida a premissa de variância constante dos modelos lineares tradicionais? Como o modelo **GARCH** resolve esse problema ao modelar a variância de ativos financeiros?
#
# **Questão 11:** Em finanças, observamos frequentemente o fenômeno de *"Volatility Clustering"* (Agrupamento de Volatilidade). Explique como o modelo GARCH captura matematicamente a ideia de que períodos de alta volatilidade tendem a ser seguidos por mais volatilidade.

# %% [markdown]
# ## **Módulo 3.4: Cointegração e Pairs Trading**

# %% [markdown]
# **Questão 12:** O conceito de **Cointegração** difere da correlação tradicional por focar em relacionamentos de longo prazo. Explique o que significa dizer que duas séries temporais, individualmente não-estacionárias, são cointegradas.
#
# **Questão 13:** Defina o que é a **Ordem de Integração**, denotada por $I(d)$. Por que é necessário que duas séries tenham a mesma ordem de integração para que possamos testar a existência de cointegração entre elas?
#
# **Questão 14:** Descreva brevemente o funcionamento do **Teste de Engle-Granger** (em dois estágios) e como ele utiliza os resíduos de uma regressão para confirmar se existe uma combinação linear estacionária entre dois ativos.
#
# **Questão 15:** Na estratégia de **Pairs Trading** (Arbitragem Estatística), como o conceito de cointegração é utilizado para identificar oportunidades de operação? Explique o que representa o "Spread" e por que apostamos na sua reversão à média.
#
# **Questão 16:** Qual é a principal diferença de aplicação entre o **Teste de Engle-Granger** e o **Teste de Johansen** quando estamos analisando uma carteira com mais de dois ativos financeiros?

# %% [markdown]
# # **Lista de Exercícios: Revisão Teórica do Módulo 04**

# %% [markdown]
# ## **Módulo 4.1: Fundamentos de Backtesting**

# %% [markdown]
# **Questão 1:** Defina o que é um **Backtest** e explique por que ele é uma etapa essencial, mas não suficiente, antes de colocar uma estratégia de investimento em conta real.
#
# **Questão 2:** Quais são os três componentes principais de um motor de simulação de backtest (dados, lógica e motor) e qual é a função específica da **lógica da estratégia** nesse processo?
#
# **Questão 3:** No contexto de backtesting, por que é perigoso focar apenas na **Rentabilidade Acumulada** sem analisar a **Volatilidade** e a **Consistência** dos retornos ao longo do tempo?

# %% [markdown]
# ## **Módulo 4.2: Estrutura e Vieses em Backtesting**

# %% [markdown]
# **Questão 4:** O **Viés de Sobrevivência (Survivorship Bias)** ocorre quando utilizamos apenas ativos que estão listados atualmente na bolsa para testar uma estratégia no passado. Explique como esse viés distorce os resultados de rentabilidade de uma carteira.
#
# **Questão 5:** Diferencie o **Look-Ahead Bias** (Viés de olhar para o futuro) do **Viés de Mineração de Dados** (Data Mining Bias/Overfitting). Forneça um exemplo prático de como um erro de código simples pode introduzir o Look-Ahead Bias em um backtest.
#
# **Questão 6:** Por que é irrealista realizar um backtest sem considerar **Custos de Transação** (corretagem, taxas da bolsa e slippage)? Como a frequência de operações de uma estratégia influencia o impacto desses custos no resultado final?
#
# **Questão 7:** O que são dados **"Point-in-Time"** e por que eles são cruciais para garantir que o backtest utilize apenas as informações que estavam efetivamente disponíveis para o investidor no momento da decisão?

# %% [markdown]
# ## **Módulo 4.3: Implementação de Backtests**

# %% [markdown]
# **Questão 8:** O **Backtesting Vetorizado (Vectorized Backtesting)** é amplamente utilizado em Python com a biblioteca Pandas. Explique como essa abordagem processa os dados e por que ela é considerada extremamente eficiente em termos computacionais.
#
# **Questão 9:** Apesar da velocidade, o backtesting vetorizado possui limitações severas em relação à realidade do mercado. Cite duas dessas limitações e explique por que elas dificultam a simulação de estratégias que dependem de ordens complexas ou múltiplos ativos.
#
# **Questão 10:** O **Backtesting Orientado a Eventos (Event-Driven Backtesting)** simula o mercado através de um loop que processa cada nova informação (tick ou barra) individualmente. Quais são as principais vantagens dessa arquitetura e por que ela é a escolha padrão para sistemas de execução institucional?
#
# **Questão 11:** Compare as duas abordagens (Vetorizada vs. Orientada a Eventos) em termos de **facilidade de implementação** e **fidelidade aos custos de transação e execução (slippage)**.

# %% [markdown]
# ## **Módulo 4.4: Métricas de Performance e Risco**

# %% [markdown]
# **Questão 12:** O **Drawdown** é uma das métricas mais importantes para a psicologia do investidor. Defina o que é o **Maximum Drawdown (MDD)** e explique por que um MDD muito alto pode invalidar uma estratégia, mesmo que ela apresente um retorno acumulado positivo no longo prazo.
#
# **Questão 13:** Os índices de Sharpe, Sortino e Calmar são usados para medir o retorno ajustado ao risco. Diferencie o **Sharpe Ratio** do **Sortino Ratio**, explicando por que o Sortino é frequentemente considerado mais justo ao analisar ativos financeiros com distribuições de retorno assimétricas.
#
# **Questão 14:** No gerenciamento de risco moderno, utilizamos o **Value at Risk (VaR)** e o **Conditional Value at Risk (CVaR)**. Explique a diferença entre eles e por que o CVaR (também chamado de Expected Shortage) é uma métrica mais conservadora e informativa sobre eventos de cauda (*tail events*).
#
# **Questão 15:** O que representa o **Alpha de Jensen** em uma análise de performance e como ele ajuda a identificar se o gestor de uma estratégia está efetivamente "batendo o mercado" através de habilidade ou apenas expondo-se ao risco sistemático (Beta)?
#
# **Questão 16:** Defina o **Omega Ratio** e explique como ele utiliza toda a distribuição de retornos para avaliar a probabilidade de se obter ganhos acima de um patamar mínimo de rentabilidade alvo.
